# %% [markdown]
# # Step 2: Speech to Text with LUIS
#
# **Content**
#
# * Speech to Text with LUIS
#     * Summarizing the classification results
# * Saving transcriptions on json files

# %%
! pip install azure-cognitiveservices-speech
# Out:
# Requirement already satisfied: azure-cognitiveservices-speech in c:\users\blueshift\appdata\local\programs\python\python38\lib\site-packages (1.23.0)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\blueshift\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
from collections import Counter
import time
import ast
import json, re
from os import listdir
import sys
import os.path

# %%
import azure.cognitiveservices.speech as speechsdk
import os, yaml, time

# %% [markdown]
# Load Configs

# %%
config_file = os.path.join("config","config.yaml")
with open(config_file, 'r') as ymlfile:
    config = yaml.load(ymlfile, Loader=yaml.FullLoader)

##### Configurações do Speech:
speech_key=config['speech']['speech_key']
speech_service_region = config['speech']['speech_region']
language=config['speech']['speech_language']

##### Configurações do LUIS
luis_app_id=config['luis_app']['app_id']

# %% [markdown]
# ## Speech to Text com LUIS

# %% [markdown]
# Referências:
# * https://github.com/Azure-Samples/cognitive-services-speech-sdk/blob/master/samples/python/console/intent_sample.py

# %%
def recognize_intent_from_speech_continuous(speech_key, speech_service_region,luis_app_id, language, file_name):
    """Método para realizar o Speech to Text integrado ao LUIS, classificando cada fala do audio com as intenções"""
    result_json = {}
    result_json['result'] = []

    # <IntentContinuousRecognitionWithFile>
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=speech_service_region, speech_recognition_language=language)
    audio_config = speechsdk.audio.AudioConfig(filename=file_name)

    # Set up the intent recognizer
    intent_recognizer = speechsdk.intent.IntentRecognizer(speech_config=speech_config, audio_config=audio_config )

    # set up the intents that are to be recognized. These can be a mix of simple phrases and
    # intents specified through a LanguageUnderstanding Model.
    model = speechsdk.intent.LanguageUnderstandingModel(app_id=luis_app_id)
    intent_recognizer.add_all_intents(model)

    # Connect callback functions to the signals the intent recognizer fires.
    done = False

    def stop_cb(evt):
        """callback that signals to stop continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        if ('SessionEventArgs' in str(evt)):
            print ("ok")
            nonlocal done
            done = True
    
    intent_recognizer.recognized.connect(lambda evt: print(
        "RECOGNIZED: {}\n\tText: {} (Reason: {})\n\tIntent Id: {}\n\tIntent JSON: {}".format(
            evt, evt.result.text, evt.result.reason, evt.result.intent_id, evt.result.intent_json, result_json['result'].append(json.loads(evt.result.intent_json)))))
    
    # cancellation event
    intent_recognizer.canceled.connect(lambda evt: print("CANCELED: {} ({})".format(evt.cancellation_details, evt.reason)))

    # stop continuous recognition on session stopped, end of speech or canceled events
    intent_recognizer.session_stopped.connect(stop_cb)
    intent_recognizer.speech_end_detected.connect(stop_cb)
    intent_recognizer.canceled.connect(stop_cb)

    # And finally run the intent recognizer. The output of the callbacks should be printed to the console.
    intent_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    intent_recognizer.stop_continuous_recognition()
    
    # </IntentContinuousRecognitionWithFile>
    return result_json

# %%
def list_files(dir):
    '''Listar arquivos em um diretório específico no SO'''
    return [f for f in os.listdir(dir) if os.path.isfile(os.path.join(dir, f))]

# %%
def realizar_transcricao_plus_intencao( container_name,files_name=None):
    ''' Realizar a transcrição + classificação das inteções de todos os audios 
        ou somente de algum específico'''
    results = {}
    if (files_name is None):
        files_name = list_files(container_name)
    for f in files_name:
        print("Processando arquivo: {}.".format(f))
        results[f] = recognize_intent_from_speech_continuous(speech_key, speech_service_region,luis_app_id, language,os.path.join(container_name, f))
    return results

# %%
######## Teste para 1 arquivo ######## 
#results_json = realizar_transcricao_plus_intencao("audios", files_name=['id_5.wav'])

# %%
######## Teste para todos os arquivos ######## 
results_json = realizar_transcricao_plus_intencao("audios")
# Out:
# Processando arquivo: id_1.wav.
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97, result=IntentRecognitionResult(result_id=2f5cf3d37331444daa0270d0f75e8451, text="São Bernardo do Campo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Bernardo do Campo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são bernardo do campo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7145854
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97, result=IntentRecognitionResult(result_id=0c629abbad2b4d6ba0dd467ac5d193ff, text="Muito obrigada pelas informações. Você poderia anotar agora? O número do protocolo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações. Você poderia anotar agora? O número do protocolo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar agora o número do protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.89981526
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97, result=IntentRecognitionResult(result_id=1588524c276c4e1eb9ffc3e11a2750f4, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8869531
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=d0b1018498dd407e9fb23d8c2b2f36b9, text="Boa tarde, me deu me a Paula, da seguradora Hebe sef, em como eu posso te ajudar?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde, me deu me a Paula, da seguradora Hebe sef, em como eu posso te ajudar? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde me deu me a paula da seguradora hebe sef em como eu posso te ajudar",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9580786
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=69bf22c7f695458eb685f02d21421b41, text="Olá, Paula. Meu nome é Maria e meu carro acaba de ser Furtado.", intent_id=classe_furto, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Paula. Meu nome é Maria e meu carro acaba de ser Furtado. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: classe_furto
# 	Intent JSON: {
#   "query": "olá paula meu nome é maria e meu carro acaba de ser furtado",
#   "topScoringIntent": {
#     "intent": "classe_furto",
#     "score": 0.14022057
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=25f235f889f24c0ea0d141f112d41876, text="Olá, Maria, eu preciso de algumas informações para registrar o seu sinistro, tudo bem?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Maria, eu preciso de algumas informações para registrar o seu sinistro, tudo bem? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "olá maria eu preciso de algumas informações para registrar o seu sinistro tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9507776
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=72fc4e19eeed47d295bd984fe9bbaf44, text="Tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97, result=IntentRecognitionResult(result_id=7799b1b147b04fae8e40bb6a1f5e70d0, text="Tem o número de protocolo é 54, 54, 5648-5458. Irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: Tem o número de protocolo é 54, 54, 5648-5458. Irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "tem o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.7839969
#   },
#   "entities": [
#     {
#       "entity": "54 54 5648 - 5458",
#       "type": "protocolo",
#       "startIndex": 28,
#       "endIndex": 42,
#       "score": 0.9877035
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97, result=IntentRecognitionResult(result_id=304306e40e294c369ea89384f6ecc75a, text="Posso ajudar em mais alguma coisa?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso ajudar em mais alguma coisa? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9635696
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=5f9090442663434bbe5c779ed37c9ee4, text="Poderia me informar a placa de seu carro?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me informar a placa de seu carro? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me informar a placa de seu carro",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9386414
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97, result=IntentRecognitionResult(result_id=4e375b7c304a47c3b3377939a66e15da, text="Não, obrigada, boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não, obrigada, boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.93987644
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97, result=IntentRecognitionResult(result_id=3c63db96c6ee4aeab130d7608b568eaf, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=14fcad9d68a24988bfb62a6a1d2bb85a, text="FDZ, 5887.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: FDZ, 5887. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "FDZ 5887",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.88168555
#   },
#   "entities": [
#     {
#       "entity": "fdz 5887",
#       "type": "placa",
#       "startIndex": 0,
#       "endIndex": 7
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# CLOSING on SessionEventArgs(session_id=17ecdb7341c44ae194afe060113c3a97)
# ok
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=36e9857eb4d343729f18a286e534af9c, text="Poderia me passar o seu nome completo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar o seu nome completo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar o seu nome completo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.92874664
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=8e8cd77df78e47b2b65f490f5a529075, text="Meu nome completo é Maria José da Silva.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu nome completo é Maria José da Silva. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu nome completo é maria josé da silva",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.21304314
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=bf0b5c5d16124d269038c0c471c9addf, text="E qual seria seu CPF?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu CPF? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu cpf",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9728561
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=b59861472af24cd1846f0c60499b40cb, text="Meu CPF é 4225, 987, 4535.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu CPF é 4225, 987, 4535. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu cpf é 4225 987 4535",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.36487544
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=5c058be0ba3047c88ce1bfb8916a31da, text="E seu e-mail?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E seu e-mail? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e seu e-mail",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7950612
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=ed16e47a1c93440fa982e725ffa2f742, text="Maria@outlook.com.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Maria@outlook.com. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "maria@outlook.com",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7369367
#   },
#   "entities": [
#     {
#       "entity": "maria@outlook.com",
#       "type": "builtin.email",
#       "startIndex": 0,
#       "endIndex": 16,
#       "resolution": {
#         "value": "maria@outlook.com"
#       }
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=26932d49566e48c6997fca88443543ce, text="E qual seria seu telefone com DDD?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu telefone com DDD? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu telefone com ddd",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.97211915
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=6dd2910cc188400685b650186046aa11, text="Meu telefone é 11 99455-4789.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu telefone é 11 99455-4789. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu telefone é 11 99455-4789",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.18054391
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=0bf7bd4cb9964111a8efc0dae75af4c6, text="Em qual rua aconteceu o furto?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Em qual rua aconteceu o furto? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "em qual rua aconteceu o furto",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9189615
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=1ddd5029b24340bc80287c72e9bfe8e1, text="Rua do girassol.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Rua do girassol. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "rua do girassol",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.80471796
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=1614e524f9164dc1b28ed4de14bd2d5f, text="Qual cidade?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.96858835
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=6eb4fbd9a4d9467b93f9edbfefa19413, text="São Paulo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Paulo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são paulo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.73453295
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=78d82101b1254f2aae2caf59ecd0aaba, text="Muito obrigada pelas informações. Você poderia anotar o número de protocolo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações. Você poderia anotar o número de protocolo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar o número de protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9322085
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=aa9e7c374c2a49939ab881eac69d68ad, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8869531
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=fc7f4dc4faa14927aa0e21fe3fc01233, text="É o número de protocolo, é 540055484552.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: É o número de protocolo, é 540055484552. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "é o número de protocolo é 540055484552",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.30210108
#   },
#   "entities": [
#     {
#       "entity": "540055484552",
#       "type": "protocolo",
#       "startIndex": 26,
#       "endIndex": 37,
#       "score": 0.72025305
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=7515054baef84999b96af42d916deb83, text="Irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.66778547
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=65394b901ed042e1a90ed1aefdb11fd0, text="Posso te ajudar em mais alguma coisa?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso te ajudar em mais alguma coisa? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso te ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9714837
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=ac5eadd3554441e3976ebb4df6798a17, text="Não, obrigada, boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não, obrigada, boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.93987644
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa, result=IntentRecognitionResult(result_id=1742a7b9f87e4d05a20ffa09e612adfa, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# CLOSING on SessionEventArgs(session_id=a7c37df11fdc4cc7bf5d967b63075caa)
# ok
# Processando arquivo: id_2.wav.
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=1667766dea674f7fb71b1c7730c703f9, text="Boa tarde. Meu nome é Camila, da seguradora Biz NF, e como eu posso te ajudar?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. Meu nome é Camila, da seguradora Biz NF, e como eu posso te ajudar? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde meu nome é camila da seguradora biz nf e como eu posso te ajudar",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8140436
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=d1cd4c266591429489f4ef9df41ff2b0, text="Olá, Camila. Meu nome é Mariana e eu acabei de bater o meu carro.", intent_id=classe_colisao, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Camila. Meu nome é Mariana e eu acabei de bater o meu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: classe_colisao
# 	Intent JSON: {
#   "query": "olá camila meu nome é mariana e eu acabei de bater o meu carro",
#   "topScoringIntent": {
#     "intent": "classe_colisao",
#     "score": 0.1576831
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=0e534c41b1f5498fba3739f28094f2eb, text="Olá, Mariana, eu preciso de algumas informações para registrar o sinistro, tudo bem?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Mariana, eu preciso de algumas informações para registrar o sinistro, tudo bem? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "olá mariana eu preciso de algumas informações para registrar o sinistro tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.939481
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=fdb3b62d01034ac5aa384afaa8ef7896, text="Tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=8edf456f5479401ca72d0aae4cf0d950, text="Poderia me passar a placa do seu carro?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar a placa do seu carro? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar a placa do seu carro",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8534573
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=68fc275ca8434d419bf80601d5ed0b33, text="BGM 2189.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: BGM 2189. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "BGM 2189",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.88168555
#   },
#   "entities": [
#     {
#       "entity": "bgm 2189",
#       "type": "placa",
#       "startIndex": 0,
#       "endIndex": 7
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=bf05d33a0f354f918488b83b9192a908, text="Poderia me passar o seu nome completo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar o seu nome completo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar o seu nome completo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.92874664
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=c8d0a7d78965431fb6fd584b39adc95f, text="Meu nome completo é Mariana Gonçalves.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu nome completo é Mariana Gonçalves. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu nome completo é mariana gonçalves",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.2100146
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=ba24045b453448afb2bbed72b88e929a, text="Qual seria o seu CPF?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Qual seria o seu CPF? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "qual seria o seu cpf",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.96631294
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=014be27e0db6467b8f56994e15767360, text="Meu CPF é 2345, 903, 5471.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu CPF é 2345, 903, 5471. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu cpf é 2345 903 5471",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.24168406
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=3c78e8cc91154bdca613cf2aad65bd09, text="E qual seria seu telefone com DDD?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu telefone com DDD? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu telefone com ddd",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.97211915
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=152c1bd53dc24ff4815ba85186dc376a, text="Meu telefone é 11 99445-8892.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu telefone é 11 99445-8892. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu telefone é 11 99445-8892",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.18054391
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=067fbdbe74c2487a88cd3ebe66fd1260, text="Esse é o e-mail.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Esse é o e-mail. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "esse é o e-mail",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.5436067
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=756b9188190d4b288f74db21a6ba8305, text="Mariana@hotmail.com.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Mariana@hotmail.com. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "mariana@hotmail.com",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7358468
#   },
#   "entities": [
#     {
#       "entity": "mariana@hotmail.com",
#       "type": "builtin.email",
#       "startIndex": 0,
#       "endIndex": 18,
#       "resolution": {
#         "value": "mariana@hotmail.com"
#       }
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=4435c69814d342ef833868ba5004cf35, text="Em qual rua aconteceu? Atualizam.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Em qual rua aconteceu? Atualizam. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "em qual rua aconteceu atualizam",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9637254
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=45c8f2dc207e4651ac7090f1df76b9d0, text="Rua das camélias.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Rua das camélias. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "rua das camélias",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7964017
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=c43a172b68fb489aa24c6df510cb1574, text="De qual cidade?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: De qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "de qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.96775544
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=485f666c855541529115224daed355e4, text="Jundiaí.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Jundiaí. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "jundiaí",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7532555
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=69a12fb807694ca8a01f94a558325e54, text="Muito obrigada pelas informações. Você poderia anotar o número de protocolo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações. Você poderia anotar o número de protocolo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar o número de protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9322085
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=e57933c5ccbe402a91b12590c6783197, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8869531
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=2df7d693d35a42d592c977db778c2248, text="E o número de protocolo é 54, 30 4579-8758.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: E o número de protocolo é 54, 30 4579-8758. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "e o número de protocolo é 54 30 4579-8758",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.4330237
#   },
#   "entities": [
#     {
#       "entity": "54 30 4579 - 8758",
#       "type": "protocolo",
#       "startIndex": 26,
#       "endIndex": 40,
#       "score": 0.89496267
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=73b39cdbf83b417982040f14bf3860e9, text="Irei encaminhar o seu caso para a área responsável, e eles irão entrar em contato com você. Posso te ajudar em mais alguma coisa.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Irei encaminhar o seu caso para a área responsável, e eles irão entrar em contato com você. Posso te ajudar em mais alguma coisa. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "irei encaminhar o seu caso para a área responsável e eles irão entrar em contato com você posso te ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.902791
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=7eac81632b494f07aa737cbf3a237a9a, text="Não, obrigada, boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não, obrigada, boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.93987644
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0, result=IntentRecognitionResult(result_id=8c6f4e43153a46ec898865da617e1085, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# CLOSING on SessionEventArgs(session_id=b3f1f1d952bd4a3f9a589e0287df40c0)
# ok
# Processando arquivo: id_3.wav.
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=aa23764eb3b147db86aade00b126ae84, text="Boa tarde. Meu nome é Bruna, da seguradora bife, e como eu posso te ajudar?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. Meu nome é Bruna, da seguradora bife, e como eu posso te ajudar? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde meu nome é bruna da seguradora bife e como eu posso te ajudar",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.83172446
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=1e58be5b599244ef9edca00b46bdc69b, text="Olá, Bruna. Meu nome é Joana, acabou de passar uma moto aqui e quebrou meu retrovisor direito.", intent_id=classe_quebra_retrovisores, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Bruna. Meu nome é Joana, acabou de passar uma moto aqui e quebrou meu retrovisor direito. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: classe_quebra_retrovisores
# 	Intent JSON: {
#   "query": "olá bruna meu nome é joana acabou de passar uma moto aqui e quebrou meu retrovisor direito",
#   "topScoringIntent": {
#     "intent": "classe_quebra_retrovisores",
#     "score": 0.30803338
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=74a86ac2433c4629aaeb96a5a920dfa3, text="Olá, Joana, eu preciso de algumas informações para registrar o seu sinistro, tudo bem?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Joana, eu preciso de algumas informações para registrar o seu sinistro, tudo bem? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "olá joana eu preciso de algumas informações para registrar o seu sinistro tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9466745
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=ba5b923208154460b78a1984c9c541ff, text="Tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=2ffee0d5cc024cdda5737c59aea82b5c, text="Poderia me informar a placa de seu carro?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me informar a placa de seu carro? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me informar a placa de seu carro",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9386414
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=9154cc5ab35a4d1c8e3c6ed6b940e4c3, text="GHT, 5841.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: GHT, 5841. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "GHT 5841",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.88168555
#   },
#   "entities": [
#     {
#       "entity": "ght 5841",
#       "type": "placa",
#       "startIndex": 0,
#       "endIndex": 7
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=77ac71cc121d4f15a0d3c746670fccb8, text="Poderia me passar o seu nome completo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar o seu nome completo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar o seu nome completo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.92874664
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=a37af8d9650046c5a221350108db3d31, text="Meu nome completo é Joana Pereira.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu nome completo é Joana Pereira. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu nome completo é joana pereira",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.2200681
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=30090c0c147c42299625a37b011894f4, text="E qual seria seu CPF?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu CPF? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu cpf",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9728561
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=251d2a54b7764bb6b9ea0358b7c495ba, text="E o CPF é 4589, 547, 8525.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E o CPF é 4589, 547, 8525. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e o cpf é 4589 547 8525",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.78645015
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=e86c45efebb64caf889f3e021d84642d, text="E seu e-mail?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E seu e-mail? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e seu e-mail",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7950612
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=095caeb5f9ee40518ffe148e0d7358ff, text="Joana@outlook.com.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Joana@outlook.com. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "joana@outlook.com",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7327753
#   },
#   "entities": [
#     {
#       "entity": "joana@outlook.com",
#       "type": "builtin.email",
#       "startIndex": 0,
#       "endIndex": 16,
#       "resolution": {
#         "value": "joana@outlook.com"
#       }
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=1155c4903c4743cf8dfef8e0aa61226d, text="E qual seria seu telefone com DDD?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu telefone com DDD? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu telefone com ddd",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.97211915
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=7505a0d6778d4373b30baa766111a01b, text="Meu telefone é 11 98554-7825.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu telefone é 11 98554-7825. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu telefone é 11 98554-7825",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.18054391
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=82decaac99fe440087e988059ed51af1, text="E foi em qual rua?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E foi em qual rua? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e foi em qual rua",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.87897134
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=a5edb3ca28c744d2ac545dc343635b81, text="Rua lua.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Rua lua. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "rua lua",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.82519335
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=283ab25164214e619e5573e76ec6eba2, text="Se, qual cidade?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Se, qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "se qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9530947
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=7332ad40904742ba97b0abacae8b6f0a, text="São Caetano do Sul.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Caetano do Sul. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são caetano do sul",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.71464765
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=fe9cdc7d8db049b3a78d50cb5298bf27, text="Muito obrigada pelas informações. Você poderia anotar o número de protocolo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações. Você poderia anotar o número de protocolo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar o número de protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9322085
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8, result=IntentRecognitionResult(result_id=ac79f8d9548f4316a9a17b0251263c61, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8869531
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9bac19fb3b6e418ba45fe2a22e5363f8)
# ...
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.93987644
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=e0d662480cff47b0bb82e33eaa8ae932)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=e0d662480cff47b0bb82e33eaa8ae932, result=IntentRecognitionResult(result_id=870ff04fb1f1436ab9f219d12a0155cc, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=e0d662480cff47b0bb82e33eaa8ae932)
# CLOSING on SessionEventArgs(session_id=e0d662480cff47b0bb82e33eaa8ae932)
# ok
# Processando arquivo: id_5.wav.
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=a0a6f55011ed4140a3ae93ae93034307, text="Boa tarde, meu nome é Paulo da seguradora, é bife que eu posso te ajudar.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde, meu nome é Paulo da seguradora, é bife que eu posso te ajudar. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde meu nome é paulo da seguradora é bife que eu posso te ajudar",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.79372895
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=d6cf2660a0d8411480df8591bb31f1d5, text="Olá, Paula. Meu nome é Júlia. Acabei de ser assaltada e roubaram meu carro.", intent_id=classe_roubo, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Paula. Meu nome é Júlia. Acabei de ser assaltada e roubaram meu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: classe_roubo
# 	Intent JSON: {
#   "query": "olá paula meu nome é júlia acabei de ser assaltada e roubaram meu carro",
#   "topScoringIntent": {
#     "intent": "classe_roubo",
#     "score": 0.3114556
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=2556ec20c28347329cfce29428169b48, text="Olá, Julia, eu preciso de algumas informações para registrar o seu sinistro, tudo bem?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Olá, Julia, eu preciso de algumas informações para registrar o seu sinistro, tudo bem? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "olá julia eu preciso de algumas informações para registrar o seu sinistro tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9483711
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=f741b1691c89457299a9cc1a53a626ce, text="Tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=487618e7c2f047088025bc7fe7f076af, text="Poderia me informar a placa do seu carro?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me informar a placa do seu carro? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me informar a placa do seu carro",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.93589944
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=2df58265716f4e2fad9fbde25c15fbb8, text="ADR 2020.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: ADR 2020. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "ADR 2020",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.73453295
#   },
#   "entities": [
#     {
#       "entity": "adr 2020",
#       "type": "placa",
#       "startIndex": 0,
#       "endIndex": 7
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=11ad654580b54a62ba2b4b6e819c1fc7, text="Poderia me passar o seu nome completo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar o seu nome completo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar o seu nome completo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.92874664
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=aa0f8045cb514c068e6f9bfb7911a614, text="Meu nome completo é Júlia Silvério.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu nome completo é Júlia Silvério. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu nome completo é júlia silvério",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.27713886
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=f0c1b2f94081460a9a91d50b9a11af06, text="E qual seria seu CPF?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu CPF? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu cpf",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9728561
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=ef78cadd295149e99e06950e2a8564b1, text="Meu CPF é 4235, 987, 4575.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu CPF é 4235, 987, 4575. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu CPF é 4235 987 4575",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.36487544
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=6ac494af31eb4adb9e9ca65034196acb, text="E o seu e-mail?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E o seu e-mail? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e o seu e-mail",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7595489
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=fe8bf092a43244159eb42224c822c82c, text="Julia@outlook.com.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Julia@outlook.com. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "julia@outlook.com",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7343312
#   },
#   "entities": [
#     {
#       "entity": "julia@outlook.com",
#       "type": "builtin.email",
#       "startIndex": 0,
#       "endIndex": 16,
#       "resolution": {
#         "value": "julia@outlook.com"
#       }
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=469379794d734a179df704b0bbfdef03, text="E qual seria seu telefone com DDD?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu telefone com DDD? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu telefone com ddd",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.97211915
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=dd71e4b7b3bd4ad587e7cc45114cdeb5, text="Meu telefone é 11 99445-8895.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu telefone é 11 99445-8895. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu telefone é 11 99445-8895",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.18054391
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=73402e95c7db478a9178f8a2d9f74d64, text="Em qual rua aconteceu o roubo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Em qual rua aconteceu o roubo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "em qual rua aconteceu o roubo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.96007913
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=9cfe190aa22a4fe9a6d0ba4698ce664f, text="Rua da Estrela.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Rua da Estrela. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "rua da estrela",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8069228
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=33be8f891132484eb1bc55fcf4085674, text="Em qual cidade?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Em qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "em qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9697071
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=01be5302f8ba4cbdaedb2160c644832d, text="São Bernardo do Campo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Bernardo do Campo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são bernardo do campo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7145854
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=7f20466c358f4eed94d408c76af410af, text="Muito obrigada pelas informações. Você poderia anotar agora? O número do protocolo?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações. Você poderia anotar agora? O número do protocolo? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar agora o número do protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.89981526
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=902ac1f6d19449cc9d291766f7d89774, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8869531
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=bfb0598c7ca04376905fcd05510a2a11, text="Tem o número de protocolo é 54, 54, 5648-5458. Irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: Tem o número de protocolo é 54, 54, 5648-5458. Irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "tem o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para a área responsável e eles irão entrar em contato com você",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.7839969
#   },
#   "entities": [
#     {
#       "entity": "54 54 5648 - 5458",
#       "type": "protocolo",
#       "startIndex": 28,
#       "endIndex": 42,
#       "score": 0.9877035
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=23ae7870894640d0a82960ef5efd6000, text="Posso ajudar em mais alguma coisa?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso ajudar em mais alguma coisa? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9635696
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=dd7e88b54a1c4a9b8f1add5015425481, text="Não, obrigada, boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não, obrigada, boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.93987644
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8, result=IntentRecognitionResult(result_id=f7d86d30a2d042ffad869f1721498f56, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.95788056
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# CLOSING on SessionEventArgs(session_id=d79a7232eb2d4da0b6d8b439181e46d8)
# ok

# %% [markdown]
# ### Summarizing the classification results
# 	* Roubo: id_5
# 	* Furto:  id_1
# 	* Colisão: OK id_2
# 	* Quebra de retrovisores: OK id_3
#     * Indefinido (enchente): OK id_4

# %%
for i in results_json.keys():
    print(i)
    print (dict(Counter(tok['topScoringIntent']['intent'] for tok in results_json[i]['result'])))
# Out:
# id_1.wav
# {'None': 23, 'classe_furto': 1, 'dizer_protocolo': 1}
# id_2.wav
# {'None': 22, 'classe_colisao': 1, 'dizer_protocolo': 1}
# id_3.wav
# {'None': 22, 'classe_quebra_retrovisores': 1, 'dizer_protocolo': 1}
# id_4.wav
# {'None': 23, 'dizer_protocolo': 1}
# id_5.wav
# {'None': 22, 'classe_roubo': 1, 'dizer_protocolo': 1}

# %% [markdown]
# ## Save transcriptions locally

# %%
def save_transcriptions(dir, results_json):
    try:
        os.makedirs(dir)
    except FileExistsError:
        print ('Directory already existis: ' + dir)
        pass
    else:
        print ('Directory successfully created: ' + dir)
    for f in results_json.keys():
        file_name = re.findall(r"(.*).wav", f)[0]
        with open(os.path.join(dir, file_name + ".json"), 'w', encoding='utf-8') as j:
            json.dump(results_json[f], j, indent=4, ensure_ascii=False)
            print("Saving file {}.json".format(file_name))

# %%
save_transcriptions("transcricoes", results_json)
# Out:
# Directory successfully created: transcricoes
# Saving file id_1.json
# Saving file id_2.json
# Saving file id_3.json
# Saving file id_4.json
# Saving file id_5.json
